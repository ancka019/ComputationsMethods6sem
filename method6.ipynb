# %% [markdown]
# <a href="https://colab.research.google.com/github/ancka019/ComputationsMethods6sem/blob/main/method6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
from copy import copy
from numpy.linalg import norm
from scipy.linalg import hilbert, eig

# %% [markdown]
# максимальный по модулю в матрице элемент

# %%
def max_abs(A): 
    i_max,j_max = 0,1
    max_item = A[i_max,j_max]
    for i in range(A.shape[0]):
        for j in range(i+1, A.shape[0]):
            if abs(max_item) < abs(A[i,j]):
                max_item = A[i, j]
                i_max, j_max = i, j
    return i_max, j_max

# %% [markdown]
#  Метод Якоби

# %%
def jacobi_method(A,eps,strategy="circle"): 
        iters = 0
        i,j = 0,0
        while True:
            h = np.identity(A.shape[0])
            if strategy == "abs":
                i,j = max_abs(A)
            else:
                if (j < (A.shape[0]-1) and j+1!=i):
                    j+=1
                elif j == A.shape[0]-1:
                    i+=1
                    j = 0
                else:
                    j+=2
            if i==A.shape[0]-1 and j==A.shape[0]:
                    return np.diag(A), iters
            if abs(A[i, j]) < eps:
                return np.diag(A), iters
            iters += 1
            phi = 0.5*(math.atan((2*A[i, j])/(A[i,i]-A[j,j])))
            c,s = math.cos(phi), math.sin(phi)
            h[i,i], h[j,j] = c,c
            h[i,j], h[j,i] = -s, s
            A = h.T@A@h

# %% [markdown]
# определение кругов Гершгорина

# %%
def gersh_circles(A): 
    ans = []
    for i in range(A.shape[0]):
        ans.append((A[i,i],sum(abs(A[i]))-abs(A[i,i])))
    return ans

# %%
def is_in_circle(gersh,lmda): #проверка в принадлежности с.ч. хотя бы одному кругу
    return any([abs(c-lmda)<=r for c,r in gersh])

# %%
result = []
for size in [3, 5, 11]:
    A = hilbert(size)
    data = []
    lambda_acc = np.sort(eig(A)[0])
    for eps in range(-6, -1):
        eps = 10**eps
        lambda_abs, abs_iters = jacobi_method(A,eps,strategy="abs")
        lambda_circle, circle_iters = jacobi_method(A,eps,strategy="circle")
        data.append({
            'eps': eps,
            'Стратегия с максимальным по модулю с.ч (К-во итераций)':
             abs_iters,
            'Стратегия с максимальным по модулю с.ч |lambda_acc - lambda|' : 
             norm(np.sort(lambda_abs)-lambda_acc),
            'Cтратегия обнуления по порядку (К-во итераций)':
             circle_iters,
            'Cтратегия обнуления по порядку |lambda_acc - lambda|' : 
             norm(np.sort(lambda_circle)-lambda_acc)
        })
    result.append(pd.DataFrame(data))

# %%
result[0]
# Out:
#         eps  Стратегия с максимальным по модулю с.ч (К-во итераций)  \
# 0  0.000001                                                  7
# 1  0.000010                                                  6
# 2  0.000100                                                  6
# 3  0.001000                                                  5
# 4  0.010000                                                  5
#
#    Стратегия с максимальным по модулю с.ч |lambda_acc - lambda|  \
# 0                                       4.236714e-16
# 1                                       2.846794e-12
# 2                                       2.846794e-12
# 3                                       3.070874e-07
# 4                                       3.070874e-07
#
#    Cтратегия обнуления по порядку (К-во итераций)  \
# 0                                               5
# 1                                               5
# 2                                               5
# 3                                               4
# 4                                               4
#
#    Cтратегия обнуления по порядку |lambda_acc - lambda|
# 0                                       4.298829e-07
# 1                                       4.298829e-07
# 2                                       4.298829e-07
# 3                                       7.479139e-07
# 4                                       7.479139e-07

# %%
result[1]
# Out:
#         eps  Стратетия с максимальным по модулю с.ч (К-во итераций)  \
# 0  0.000001                                                 24
# 1  0.000010                                                 24
# 2  0.000100                                                 18
# 3  0.001000                                                 17
# 4  0.010000                                                 11
#
#    Стратетия с максимальным по модулю с.ч |lambda_acc - lambda|  \
# 0                                       3.994225e-11
# 1                                       3.994225e-11
# 2                                       2.186581e-07
# 3                                       1.008748e-04
# 4                                       8.019429e-03
#
#    Cтретия обнуления по порядку (К-во итераций)  \
# 0                                            20
# 1                                            20
# 2                                            19
# 3                                            11
# 4                                             9
#
#    Cтретия обнуления по порядку |lambda_acc - lambda|
# 0                                           0.000432
# 1                                           0.000432
# 2                                           0.000432
# 3                                           0.006620
# 4                                           0.008005

# %%
result[2]
# Out:
#         eps  Стратегия с максимальным по модулю с.ч (К-во итераций)  \
# 0  0.000001                                                108
# 1  0.000010                                                 93
# 2  0.000100                                                 78
# 3  0.001000                                                 51
# 4  0.010000                                                 27
#
#    Стратегия с максимальным по модулю с.ч |lambda_acc - lambda|  \
# 0                                       8.194918e-08
# 1                                       4.959629e-06
# 2                                       1.487451e-04
# 3                                       2.347574e-03
# 4                                       3.710672e-02
#
#    Cтратегия обнуления по порядку (К-во итераций)  \
# 0                                              27
# 1                                              24
# 2                                              24
# 3                                              23
# 4                                              21
#
#    Cтратегия обнуления по порядку |lambda_acc - lambda|
# 0                                           0.036646
# 1                                           0.036646
# 2                                           0.036646
# 3                                           0.036645
# 4                                           0.037446
